# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("./data/BTCUSDT_1h.csv")

# %%
df = df.sort_values('close_time')
features = ['open', 'high', 'low', 'close', 'volume']
data = df[features].values

# %%
# Normalize
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)

# %%
# Create sequences
def create_sequences(data, seq_len):
    sequences = []
    for i in range(len(data) - seq_len):
        sequences.append(data[i:i+seq_len])
    return np.array(sequences)

SEQ_LEN = 24  # e.g., 24 hourly steps
X = create_sequences(data_scaled, SEQ_LEN)

# %%
# Convert to torch tensors
X_tensor = torch.tensor(X, dtype=torch.float32)

# Split into training and validation datasets
X_train, X_val = train_test_split(X_tensor, test_size=0.1, shuffle=False)

# DataLoader for batching
train_loader = DataLoader(TensorDataset(X_train), batch_size=32, shuffle=True)
val_loader = DataLoader(TensorDataset(X_val), batch_size=32, shuffle=False)

# %%
class LSTM_Autoencoder(nn.Module):
    def __init__(self, input_dim, hidden_dim, seq_len):
        super(LSTM_Autoencoder, self).__init__()
        self.seq_len = seq_len
        
        # Encoder
        self.encoder = nn.LSTM(input_dim, hidden_dim, batch_first=True)
        
        # Decoder
        self.decoder = nn.LSTM(hidden_dim, input_dim, batch_first=True)
        
        self.fc = nn.Linear(input_dim, input_dim)
    
    def forward(self, x):
        batch_size = x.size(0)

        # Encoder
        _, (hidden, _) = self.encoder(x)

        # Repeat the hidden state SEQ_LEN times
        decoder_input = hidden.repeat(self.seq_len, 1, 1).permute(1, 0, 2)  # [batch_size, seq_len, hidden_dim]

        # Decoder
        decoded, _ = self.decoder(decoder_input)

        # Project back to original feature space
        decoded = self.fc(decoded)
        return decoded

# %%
# Initialize model
input_dim = X.shape[2]  # Number of features
hidden_dim = 124  # Size of the LSTM hidden layer

model = LSTM_Autoencoder(input_dim, hidden_dim, SEQ_LEN)

# %%
# Loss function and optimizer
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.007729558899578971)

# %%
# Learning rate scheduler
lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.5, verbose=True)
# Out:
# C:\Users\josiw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %%
# Function to compute RMSE (Root Mean Squared Error)
def rmse(y_true, y_pred):
    return torch.sqrt(torch.mean((y_true - y_pred) ** 2))

# Function to compute MAE (Mean Absolute Error)
def mae(y_true, y_pred):
    return torch.mean(torch.abs(y_true - y_pred))

# %%
# Training loop
num_epochs = 50

train_losses, val_losses, lrs, rmse_values, mae_values = [], [], [], [], []

# %%
for epoch in range(num_epochs):
    model.train()
    epoch_train_loss = 0.0
    epoch_rmse = 0.0
    epoch_mae = 0.0

    lr = optimizer.param_groups[0]['lr']

    for batch in train_loader:
        X_batch = batch[0]
        
        # Forward pass
        optimizer.zero_grad()
        output = model(X_batch)
        
        # Compute loss
        loss = criterion(output, X_batch)
        

        epoch_rmse += rmse(X_batch, output).item()
        epoch_mae += mae(X_batch, output).item()
        

        # Backward pass
        loss.backward()
        optimizer.step()
        
        epoch_train_loss += loss.item()
    

    avg_train_loss = epoch_train_loss / len(train_loader)
    avg_rmse = epoch_rmse / len(train_loader)
    avg_mae = epoch_mae / len(train_loader)
    
    model.eval()
    epoch_val_loss = 0.0
    epoch_val_rmse = 0.0
    epoch_val_mae = 0.0


    with torch.no_grad():
        for batch in val_loader:
            X_batch = batch[0]
            output = model(X_batch)

            loss = criterion(output, X_batch)
            epoch_val_loss += loss.item()
            
            # Compute validation RMSE and MAE
            epoch_val_rmse += rmse(X_batch, output).item()
            epoch_val_mae += mae(X_batch, output).item()
    
    avg_val_loss = epoch_val_loss / len(val_loader)
    avg_val_rmse = epoch_val_rmse / len(val_loader)
    avg_val_mae = epoch_val_mae / len(val_loader)

    # Calculate the average loss
    avg_train_loss = epoch_train_loss / len(train_loader)
    
    train_losses.append(avg_train_loss)
    val_losses.append(avg_val_loss)
    lrs.append(lr)
    rmse_values.append(avg_val_rmse)
    mae_values.append(avg_val_mae)
    
    # Step the learning rate scheduler
    lr_scheduler.step(avg_val_loss)
    
    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}')
    print(f'\tRMSE (Train): {avg_rmse:.4f}, RMSE (Val): {avg_val_rmse:.4f}')
    print(f'\tMAE (Train): {avg_mae:.4f}, MAE (Val): {avg_val_mae:.4f}')
# Out:
# Epoch [1/50], Train Loss: 0.0011, Val Loss: 0.0006
# 	RMSE (Train): 0.0244, RMSE (Val): 0.0224
# 	MAE (Train): 0.0139, MAE (Val): 0.0175
# Epoch [2/50], Train Loss: 0.0003, Val Loss: 0.0006
# 	RMSE (Train): 0.0175, RMSE (Val): 0.0230
# 	MAE (Train): 0.0086, MAE (Val): 0.0194
# Epoch [3/50], Train Loss: 0.0003, Val Loss: 0.0004
# 	RMSE (Train): 0.0169, RMSE (Val): 0.0173
# 	MAE (Train): 0.0080, MAE (Val): 0.0115
# Epoch [4/50], Train Loss: 0.0003, Val Loss: 0.0008
# 	RMSE (Train): 0.0164, RMSE (Val): 0.0271
# 	MAE (Train): 0.0075, MAE (Val): 0.0238
# Epoch [5/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0162, RMSE (Val): 0.0153
# 	MAE (Train): 0.0071, MAE (Val): 0.0101
# Epoch [6/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0161, RMSE (Val): 0.0161
# 	MAE (Train): 0.0071, MAE (Val): 0.0106
# Epoch [7/50], Train Loss: 0.0003, Val Loss: 0.0017
# 	RMSE (Train): 0.0160, RMSE (Val): 0.0403
# 	MAE (Train): 0.0068, MAE (Val): 0.0370
# Epoch [8/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0159, RMSE (Val): 0.0151
# 	MAE (Train): 0.0065, MAE (Val): 0.0105
# Epoch [9/50], Train Loss: 0.0003, Val Loss: 0.0004
# 	RMSE (Train): 0.0158, RMSE (Val): 0.0176
# 	MAE (Train): 0.0065, MAE (Val): 0.0130
# Epoch [10/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0157, RMSE (Val): 0.0145
# 	MAE (Train): 0.0064, MAE (Val): 0.0095
# Epoch [11/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0158, RMSE (Val): 0.0145
# 	MAE (Train): 0.0064, MAE (Val): 0.0097
# Epoch [12/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0156, RMSE (Val): 0.0153
# 	MAE (Train): 0.0063, MAE (Val): 0.0105
# Epoch [13/50], Train Loss: 0.0002, Val Loss: 0.0002
# 	RMSE (Train): 0.0155, RMSE (Val): 0.0141
# 	MAE (Train): 0.0061, MAE (Val): 0.0089
# Epoch [14/50], Train Loss: 0.0002, Val Loss: 0.0003
# 	RMSE (Train): 0.0154, RMSE (Val): 0.0148
# 	MAE (Train): 0.0060, MAE (Val): 0.0094
# Epoch [15/50], Train Loss: 0.0002, Val Loss: 0.0002
# 	RMSE (Train): 0.0154, RMSE (Val): 0.0137
# 	MAE (Train): 0.0062, MAE (Val): 0.0080
# Epoch [16/50], Train Loss: 0.0002, Val Loss: 0.0003
# 	RMSE (Train): 0.0151, RMSE (Val): 0.0156
# 	MAE (Train): 0.0061, MAE (Val): 0.0107
# Epoch [17/50], Train Loss: 0.0002, Val Loss: 0.0003
# 	RMSE (Train): 0.0147, RMSE (Val): 0.0169
# 	MAE (Train): 0.0060, MAE (Val): 0.0125
# Epoch [18/50], Train Loss: 0.0002, Val Loss: 0.0002
# 	RMSE (Train): 0.0143, RMSE (Val): 0.0137
# 	MAE (Train): 0.0059, MAE (Val): 0.0081
# Epoch [19/50], Train Loss: 0.0002, Val Loss: 0.0053
# 	RMSE (Train): 0.0140, RMSE (Val): 0.0721
# 	MAE (Train): 0.0057, MAE (Val): 0.0675
# Epoch [20/50], Train Loss: 0.0002, Val Loss: 0.0003
# 	RMSE (Train): 0.0142, RMSE (Val): 0.0173
# 	MAE (Train): 0.0059, MAE (Val): 0.0139
# Epoch [21/50], Train Loss: 0.0002, Val Loss: 0.0002
# 	RMSE (Train): 0.0136, RMSE (Val): 0.0136
# 	MAE (Train): 0.0055, MAE (Val): 0.0093
# Epoch [22/50], Train Loss: 0.0002, Val Loss: 0.0002
# 	RMSE (Train): 0.0135, RMSE (Val): 0.0126
# 	MAE (Train): 0.0055, MAE (Val): 0.0078
# Epoch [23/50], Train Loss: 0.0002, Val Loss: 0.0002
# 	RMSE (Train): 0.0133, RMSE (Val): 0.0130
# 	MAE (Train): 0.0056, MAE (Val): 0.0082
# Epoch [24/50], Train Loss: 0.0002, Val Loss: 0.0002
# 	RMSE (Train): 0.0131, RMSE (Val): 0.0121
# 	MAE (Train): 0.0055, MAE (Val): 0.0075
# Epoch [25/50], Train Loss: 0.0002, Val Loss: 0.0002
# 	RMSE (Train): 0.0129, RMSE (Val): 0.0122
# 	MAE (Train): 0.0055, MAE (Val): 0.0076
# Epoch [26/50], Train Loss: 0.0002, Val Loss: 0.0002
# 	RMSE (Train): 0.0127, RMSE (Val): 0.0118
# 	MAE (Train): 0.0053, MAE (Val): 0.0073
# Epoch [27/50], Train Loss: 0.0002, Val Loss: 0.0002
# 	RMSE (Train): 0.0126, RMSE (Val): 0.0120
# 	MAE (Train): 0.0054, MAE (Val): 0.0075
# Epoch [28/50], Train Loss: 0.0002, Val Loss: 0.0002
# 	RMSE (Train): 0.0125, RMSE (Val): 0.0118
# 	MAE (Train): 0.0052, MAE (Val): 0.0074
# Epoch [29/50], Train Loss: 0.0002, Val Loss: 0.0003
# 	RMSE (Train): 0.0124, RMSE (Val): 0.0151
# 	MAE (Train): 0.0052, MAE (Val): 0.0112
# Epoch [30/50], Train Loss: 0.0002, Val Loss: 0.0002
# 	RMSE (Train): 0.0123, RMSE (Val): 0.0120
# 	MAE (Train): 0.0051, MAE (Val): 0.0073
# Epoch [31/50], Train Loss: 0.0001, Val Loss: 0.0003
# 	RMSE (Train): 0.0120, RMSE (Val): 0.0157
# 	MAE (Train): 0.0050, MAE (Val): 0.0125
# Epoch [32/50], Train Loss: 0.0002, Val Loss: 0.0008
# 	RMSE (Train): 0.0120, RMSE (Val): 0.0273
# 	MAE (Train): 0.0052, MAE (Val): 0.0201
# Epoch [33/50], Train Loss: 0.0001, Val Loss: 0.0002
# 	RMSE (Train): 0.0113, RMSE (Val): 0.0123
# 	MAE (Train): 0.0045, MAE (Val): 0.0085
# Epoch [34/50], Train Loss: 0.0001, Val Loss: 0.0002
# 	RMSE (Train): 0.0112, RMSE (Val): 0.0128
# 	MAE (Train): 0.0045, MAE (Val): 0.0088
# Epoch [35/50], Train Loss: 0.0001, Val Loss: 0.0002
# 	RMSE (Train): 0.0112, RMSE (Val): 0.0116
# 	MAE (Train): 0.0046, MAE (Val): 0.0072
# Epoch [36/50], Train Loss: 0.0001, Val Loss: 0.0002
# 	RMSE (Train): 0.0111, RMSE (Val): 0.0148
# 	MAE (Train): 0.0045, MAE (Val): 0.0106
# Epoch [37/50], Train Loss: 0.0001, Val Loss: 0.0001
# 	RMSE (Train): 0.0110, RMSE (Val): 0.0112
# 	MAE (Train): 0.0045, MAE (Val): 0.0072
# Epoch [38/50], Train Loss: 0.0001, Val Loss: 0.0001
# 	RMSE (Train): 0.0111, RMSE (Val): 0.0112
# 	MAE (Train): 0.0045, MAE (Val): 0.0070
# Epoch [39/50], Train Loss: 0.0001, Val Loss: 0.0002
# 	RMSE (Train): 0.0110, RMSE (Val): 0.0121
# 	MAE (Train): 0.0045, MAE (Val): 0.0079
# Epoch [40/50], Train Loss: 0.0001, Val Loss: 0.0002
# 	RMSE (Train): 0.0110, RMSE (Val): 0.0126
# 	MAE (Train): 0.0045, MAE (Val): 0.0087
# Epoch [41/50], Train Loss: 0.0001, Val Loss: 0.0002
# 	RMSE (Train): 0.0109, RMSE (Val): 0.0120
# 	MAE (Train): 0.0045, MAE (Val): 0.0079
# Epoch [42/50], Train Loss: 0.0001, Val Loss: 0.0001
# 	RMSE (Train): 0.0111, RMSE (Val): 0.0109
# 	MAE (Train): 0.0046, MAE (Val): 0.0065
# Epoch [43/50], Train Loss: 0.0001, Val Loss: 0.0001
# 	RMSE (Train): 0.0108, RMSE (Val): 0.0110
# 	MAE (Train): 0.0044, MAE (Val): 0.0067
# Epoch [44/50], Train Loss: 0.0001, Val Loss: 0.0001
# 	RMSE (Train): 0.0108, RMSE (Val): 0.0108
# 	MAE (Train): 0.0044, MAE (Val): 0.0066
# Epoch [45/50], Train Loss: 0.0001, Val Loss: 0.0001
# 	RMSE (Train): 0.0110, RMSE (Val): 0.0110
# 	MAE (Train): 0.0045, MAE (Val): 0.0069
# Epoch [46/50], Train Loss: 0.0001, Val Loss: 0.0002
# 	RMSE (Train): 0.0108, RMSE (Val): 0.0140
# 	MAE (Train): 0.0045, MAE (Val): 0.0105
# Epoch [47/50], Train Loss: 0.0001, Val Loss: 0.0001
# 	RMSE (Train): 0.0108, RMSE (Val): 0.0112
# 	MAE (Train): 0.0045, MAE (Val): 0.0068
# Epoch [48/50], Train Loss: 0.0001, Val Loss: 0.0001
# 	RMSE (Train): 0.0107, RMSE (Val): 0.0112
# 	MAE (Train): 0.0044, MAE (Val): 0.0071
# Epoch [49/50], Train Loss: 0.0001, Val Loss: 0.0003
# 	RMSE (Train): 0.0108, RMSE (Val): 0.0167
# 	MAE (Train): 0.0044, MAE (Val): 0.0123
# Epoch [50/50], Train Loss: 0.0001, Val Loss: 0.0002
# 	RMSE (Train): 0.0107, RMSE (Val): 0.0124
# 	MAE (Train): 0.0044, MAE (Val): 0.0084

# %%
# Compute reconstruction error on validation set
model.eval()
reconstruction_errors = []
with torch.no_grad():
    for batch in val_loader:
        X_batch = batch[0]
        output = model(X_batch)
        loss = torch.mean((output - X_batch) ** 2, dim=(1,2))  # MSE for each sequence
        reconstruction_errors.extend(loss.numpy())

num_sequences = len(X)

# Get number of validation samples
num_val = len(X_val)

# Find the starting index in the original DataFrame
val_start_idx = num_sequences - num_val

# Align the original dataframe accordingly
df_plot = df.iloc[SEQ_LEN + val_start_idx:].copy()

# Add reconstruction errors
df_plot['reconstruction_error'] = reconstruction_errors

# %%
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.legend()
plt.title('Losses')

plt.subplot(1, 2, 2)
plt.plot(lrs, label='Learning Rate')
plt.plot(rmse_values, label='RMSE')
plt.plot(mae_values, label='MAE')
plt.legend()
plt.title('LR, RMSE, MAE')
plt.tight_layout()
plt.show()

# %%
model.eval()
reconstructions = []
errors = []

with torch.no_grad():
    for batch in DataLoader(TensorDataset(X_tensor), batch_size=32, shuffle=False):
        X_batch = batch[0]
        output = model(X_batch)
        reconstructions.append(output)
        
        # Per-sequence error (MSE)
        batch_errors = torch.mean((output - X_batch) ** 2, dim=(1, 2))  # mean over seq_len and features
        errors.append(batch_errors)

reconstructions = torch.cat(reconstructions)
errors = torch.cat(errors).numpy()  # Shape: [num_sequences]

# %%
threshold = np.percentile(errors, 95)  # Top 5% as anomalies

# %%
anomalies = errors > threshold

# %%
timestamps = df['close_time'].values[SEQ_LEN:] 

plt.figure(figsize=(15, 4))
plt.plot(timestamps, errors, label="Reconstruction Error")
plt.axhline(y=threshold, color='r', linestyle='--', label="Threshold")
plt.fill_between(timestamps, 0, errors, where=anomalies, color='red', alpha=0.3, label="Anomalies")
plt.legend()
plt.title("Anomaly Detection via LSTM Autoencoder")
plt.xlabel("Time")
plt.ylabel("Error")
plt.show()

# %%
# Number of anomalies
print(f"Total anomalies detected: {np.sum(anomalies)}")
# Out:
# Total anomalies detected: 1922

# %%
close_index = df.columns.get_loc("close") - 1 

recon_close = reconstructions[:, -1, close_index].numpy()
actual_close = X_tensor[:, -1, close_index].numpy()

base_index = SEQ_LEN 
anomaly_df = df.iloc[base_index:][anomalies].copy()  # only anomalies

anomaly_df['predicted_close'] = recon_close[anomalies]
anomaly_df['actual_close'] = actual_close[anomalies]
anomaly_df['abs_error'] = np.abs(anomaly_df['actual_close'] - anomaly_df['predicted_close'])

anomaly_df.to_csv("results/lstm_autoencoder_anomalies.csv", index=False)
print("Anomalies saved to lstm_autoencoder_anomalies.csv")
# Out:
# Anomalies saved to lstm_autoencoder_anomalies.csv

# %%
df2 = pd.read_csv("results/lstm_autoencoder_anomalies.csv")

# %%
df2.head()
# Out:
#       open     high      low    close        volume  \
# 0  7685.55  7780.00  7569.83  7686.93   7501.318100
# 1  7686.93  7739.80  7627.00  7683.18   3525.785109
# 2  7644.00  7650.00  7582.31  7614.21   2132.633589
# 3  7410.09  7432.63  6859.64  6860.25  14635.970299
# 4  4542.98  4588.00  4453.18  4457.71   3233.989280
#
#                          close_time         quote  takers_buy_base  \
# 0  2018-04-12 07:59:59.999000-05:00  5.754492e+07      3534.788744
# 1  2018-04-12 08:59:59.999000-05:00  2.710017e+07      1662.304104
# 2  2018-04-12 10:59:59.999000-05:00  1.625165e+07      1214.426837
# 3  2018-10-15 02:59:59.999000-05:00  1.045018e+08      6939.937831
# 4  2018-11-20 17:59:59.999000-05:00  1.461929e+07      1547.942542
#
#    takers_buy_quote  predicted_close  actual_close  abs_error
# 0      2.712034e+07         0.063059      0.062742   0.000317
# 1      1.278317e+07         0.063610      0.072414   0.008804
# 2      9.254198e+06         0.064825      0.072523   0.007698
# 3      4.961709e+07         0.055130      0.059104   0.003973
# 4      6.997856e+06         0.031740      0.024515   0.007225
