# %%
import pandas as pd
import numpy as np
import torch
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("./data/BTCUSDT_1h.csv")

# %%
df = df.sort_values('close_time')
features = ['open', 'high', 'low', 'close', 'volume']
data = df[features].values

# %%
# Normalize
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)

# %%
# Create sequences
def create_sequences(data, seq_len):
    sequences = []
    for i in range(len(data) - seq_len):
        sequences.append(data[i:i+seq_len])
    return np.array(sequences)

SEQ_LEN = 24  # e.g., 24 hourly steps
X = create_sequences(data_scaled, SEQ_LEN)

# %%
# Convert to torch tensors
X_tensor = torch.tensor(X, dtype=torch.float32)

# Split into training and validation datasets
X_train, X_val = train_test_split(X_tensor, test_size=0.1, shuffle=False)

# DataLoader for batching
train_loader = DataLoader(TensorDataset(X_train), batch_size=32, shuffle=True)
val_loader = DataLoader(TensorDataset(X_val), batch_size=32, shuffle=False)

# %%
import torch.nn as nn
import torch.optim as optim

class LSTM_Autoencoder(nn.Module):
    def __init__(self, input_dim, hidden_dim, seq_len):
        super(LSTM_Autoencoder, self).__init__()
        self.seq_len = seq_len
        
        # Encoder
        self.encoder = nn.LSTM(input_dim, hidden_dim, batch_first=True)
        
        # Decoder
        self.decoder = nn.LSTM(hidden_dim, input_dim, batch_first=True)
        
        self.fc = nn.Linear(input_dim, input_dim)
    
    def forward(self, x):
        batch_size = x.size(0)

        # Encoder
        _, (hidden, _) = self.encoder(x)

        # Repeat the hidden state SEQ_LEN times
        decoder_input = hidden.repeat(self.seq_len, 1, 1).permute(1, 0, 2)  # [batch_size, seq_len, hidden_dim]

        # Decoder
        decoded, _ = self.decoder(decoder_input)

        # Project back to original feature space
        decoded = self.fc(decoded)
        return decoded

# %%
# Initialize model
input_dim = X.shape[2]  # Number of features
hidden_dim = 64  # Size of the LSTM hidden layer

model = LSTM_Autoencoder(input_dim, hidden_dim, SEQ_LEN)

# %%
# Loss function and optimizer
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# Learning rate scheduler
lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.5, verbose=True)
# Out:
# C:\Users\josiw\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %%
# Function to compute RMSE (Root Mean Squared Error)
def rmse(y_true, y_pred):
    return torch.sqrt(torch.mean((y_true - y_pred) ** 2))

# Function to compute MAE (Mean Absolute Error)
def mae(y_true, y_pred):
    return torch.mean(torch.abs(y_true - y_pred))

# %%
# Training loop
num_epochs = 50

train_losses, val_losses, lrs, rmse_values, mae_values = [], [], [], [], []

# %%
for epoch in range(num_epochs):
    model.train()
    epoch_train_loss = 0.0
    epoch_rmse = 0.0
    epoch_mae = 0.0

    lr_scheduler.step(avg_val_loss)
    lr = optimizer.param_groups[0]['lr']

    for batch in train_loader:
        X_batch = batch[0]
        
        # Forward pass
        optimizer.zero_grad()
        output = model(X_batch)
        
        # Compute loss
        loss = criterion(output, X_batch)
        

        epoch_rmse += rmse(X_batch, output).item()
        epoch_mae += mae(X_batch, output).item()
        

        # Backward pass
        loss.backward()
        optimizer.step()
        
        epoch_train_loss += loss.item()
    

    avg_train_loss = epoch_train_loss / len(train_loader)
    avg_rmse = epoch_rmse / len(train_loader)
    avg_mae = epoch_mae / len(train_loader)
    
    model.eval()
    epoch_val_loss = 0.0
    epoch_val_rmse = 0.0
    epoch_val_mae = 0.0


    with torch.no_grad():
        for batch in val_loader:
            X_batch = batch[0]
            output = model(X_batch)

            loss = criterion(output, X_batch)
            epoch_val_loss += loss.item()
            
            # Compute validation RMSE and MAE
            epoch_val_rmse += rmse(X_batch, output).item()
            epoch_val_mae += mae(X_batch, output).item()
    
    avg_val_loss = epoch_val_loss / len(val_loader)
    avg_val_rmse = epoch_val_rmse / len(val_loader)
    avg_val_mae = epoch_val_mae / len(val_loader)

    # Calculate the average loss
    avg_train_loss = epoch_train_loss / len(train_loader)
    
    train_losses.append(avg_train_loss)
    val_losses.append(avg_val_loss)
    lrs.append(lr)
    rmse_values.append(avg_val_rmse)
    mae_values.append(avg_val_mae)
    
    # Step the learning rate scheduler
    lr_scheduler.step(avg_val_loss)
    
    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}')
    print(f'\tRMSE (Train): {avg_rmse:.4f}, RMSE (Val): {avg_val_rmse:.4f}')
    print(f'\tMAE (Train): {avg_mae:.4f}, MAE (Val): {avg_val_mae:.4f}')
# Out:
# Epoch [1/50], Train Loss: 0.0074, Val Loss: 0.0018
# 	RMSE (Train): 0.0512, RMSE (Val): 0.0395
# 	MAE (Train): 0.0299, MAE (Val): 0.0242
# Epoch [2/50], Train Loss: 0.0004, Val Loss: 0.0008
# 	RMSE (Train): 0.0201, RMSE (Val): 0.0273
# 	MAE (Train): 0.0100, MAE (Val): 0.0178
# Epoch [3/50], Train Loss: 0.0003, Val Loss: 0.0006
# 	RMSE (Train): 0.0174, RMSE (Val): 0.0221
# 	MAE (Train): 0.0082, MAE (Val): 0.0147
# Epoch [4/50], Train Loss: 0.0003, Val Loss: 0.0008
# 	RMSE (Train): 0.0168, RMSE (Val): 0.0264
# 	MAE (Train): 0.0077, MAE (Val): 0.0216
# Epoch [5/50], Train Loss: 0.0003, Val Loss: 0.0012
# 	RMSE (Train): 0.0163, RMSE (Val): 0.0335
# 	MAE (Train): 0.0071, MAE (Val): 0.0293
# Epoch [6/50], Train Loss: 0.0003, Val Loss: 0.0007
# 	RMSE (Train): 0.0163, RMSE (Val): 0.0254
# 	MAE (Train): 0.0071, MAE (Val): 0.0215
# Epoch [7/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0161, RMSE (Val): 0.0163
# 	MAE (Train): 0.0070, MAE (Val): 0.0111
# Epoch [8/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0162, RMSE (Val): 0.0160
# 	MAE (Train): 0.0070, MAE (Val): 0.0111
# Epoch [9/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0159, RMSE (Val): 0.0162
# 	MAE (Train): 0.0066, MAE (Val): 0.0115
# Epoch [10/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0160, RMSE (Val): 0.0161
# 	MAE (Train): 0.0067, MAE (Val): 0.0112
# Epoch [11/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0160, RMSE (Val): 0.0154
# 	MAE (Train): 0.0068, MAE (Val): 0.0104
# Epoch [12/50], Train Loss: 0.0003, Val Loss: 0.0006
# 	RMSE (Train): 0.0158, RMSE (Val): 0.0230
# 	MAE (Train): 0.0063, MAE (Val): 0.0194
# Epoch [13/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0159, RMSE (Val): 0.0157
# 	MAE (Train): 0.0065, MAE (Val): 0.0110
# Epoch [14/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0158, RMSE (Val): 0.0156
# 	MAE (Train): 0.0063, MAE (Val): 0.0110
# Epoch [15/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0159, RMSE (Val): 0.0158
# 	MAE (Train): 0.0065, MAE (Val): 0.0112
# Epoch [16/50], Train Loss: 0.0003, Val Loss: 0.0019
# 	RMSE (Train): 0.0157, RMSE (Val): 0.0432
# 	MAE (Train): 0.0061, MAE (Val): 0.0403
# Epoch [17/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0158, RMSE (Val): 0.0148
# 	MAE (Train): 0.0064, MAE (Val): 0.0100
# Epoch [18/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0158, RMSE (Val): 0.0149
# 	MAE (Train): 0.0063, MAE (Val): 0.0101
# Epoch [19/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0157, RMSE (Val): 0.0154
# 	MAE (Train): 0.0062, MAE (Val): 0.0106
# Epoch [20/50], Train Loss: 0.0003, Val Loss: 0.0018
# 	RMSE (Train): 0.0157, RMSE (Val): 0.0416
# 	MAE (Train): 0.0063, MAE (Val): 0.0390
# Epoch [21/50], Train Loss: 0.0003, Val Loss: 0.0010
# 	RMSE (Train): 0.0158, RMSE (Val): 0.0309
# 	MAE (Train): 0.0063, MAE (Val): 0.0269
# Epoch [22/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0157, RMSE (Val): 0.0147
# 	MAE (Train): 0.0062, MAE (Val): 0.0099
# Epoch [23/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0162, RMSE (Val): 0.0166
# 	MAE (Train): 0.0067, MAE (Val): 0.0119
# Epoch [24/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0157, RMSE (Val): 0.0157
# 	MAE (Train): 0.0060, MAE (Val): 0.0110
# Epoch [25/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0157, RMSE (Val): 0.0155
# 	MAE (Train): 0.0061, MAE (Val): 0.0108
# Epoch [26/50], Train Loss: 0.0003, Val Loss: 0.0006
# 	RMSE (Train): 0.0157, RMSE (Val): 0.0231
# 	MAE (Train): 0.0062, MAE (Val): 0.0194
# Epoch [27/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0157, RMSE (Val): 0.0151
# 	MAE (Train): 0.0062, MAE (Val): 0.0103
# Epoch [28/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0157, RMSE (Val): 0.0150
# 	MAE (Train): 0.0061, MAE (Val): 0.0102
# Epoch [29/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0156, RMSE (Val): 0.0146
# 	MAE (Train): 0.0058, MAE (Val): 0.0098
# Epoch [30/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0157, RMSE (Val): 0.0151
# 	MAE (Train): 0.0059, MAE (Val): 0.0104
# Epoch [31/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0157, RMSE (Val): 0.0149
# 	MAE (Train): 0.0060, MAE (Val): 0.0101
# Epoch [32/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0156, RMSE (Val): 0.0148
# 	MAE (Train): 0.0058, MAE (Val): 0.0100
# Epoch [33/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0156, RMSE (Val): 0.0161
# 	MAE (Train): 0.0059, MAE (Val): 0.0116
# Epoch [34/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0156, RMSE (Val): 0.0148
# 	MAE (Train): 0.0059, MAE (Val): 0.0098
# Epoch [35/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0156, RMSE (Val): 0.0148
# 	MAE (Train): 0.0058, MAE (Val): 0.0100
# Epoch [36/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0156, RMSE (Val): 0.0149
# 	MAE (Train): 0.0058, MAE (Val): 0.0101
# Epoch [37/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0156, RMSE (Val): 0.0146
# 	MAE (Train): 0.0058, MAE (Val): 0.0099
# Epoch [38/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0156, RMSE (Val): 0.0147
# 	MAE (Train): 0.0058, MAE (Val): 0.0099
# Epoch [39/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0156, RMSE (Val): 0.0148
# 	MAE (Train): 0.0058, MAE (Val): 0.0099
# Epoch [40/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0156, RMSE (Val): 0.0162
# 	MAE (Train): 0.0058, MAE (Val): 0.0116
# Epoch [41/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0156, RMSE (Val): 0.0146
# 	MAE (Train): 0.0058, MAE (Val): 0.0098
# Epoch [42/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0156, RMSE (Val): 0.0146
# 	MAE (Train): 0.0058, MAE (Val): 0.0097
# Epoch [43/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0156, RMSE (Val): 0.0146
# 	MAE (Train): 0.0058, MAE (Val): 0.0097
# Epoch [44/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0156, RMSE (Val): 0.0146
# 	MAE (Train): 0.0058, MAE (Val): 0.0098
# Epoch [45/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0156, RMSE (Val): 0.0146
# 	MAE (Train): 0.0058, MAE (Val): 0.0097
# Epoch [46/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0156, RMSE (Val): 0.0146
# 	MAE (Train): 0.0058, MAE (Val): 0.0097
# Epoch [47/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0156, RMSE (Val): 0.0145
# 	MAE (Train): 0.0058, MAE (Val): 0.0096
# Epoch [48/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0156, RMSE (Val): 0.0145
# 	MAE (Train): 0.0058, MAE (Val): 0.0097
# Epoch [49/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0156, RMSE (Val): 0.0147
# 	MAE (Train): 0.0058, MAE (Val): 0.0097
# Epoch [50/50], Train Loss: 0.0003, Val Loss: 0.0003
# 	RMSE (Train): 0.0156, RMSE (Val): 0.0144
# 	MAE (Train): 0.0058, MAE (Val): 0.0094

# %%
# Assuming train_losses, val_losses, lrs, rmse_values, mae_values are all lists of length 50
epochs = list(range(1, 51))  # Epochs 1 through 50

plt.figure(figsize=(18, 5))

# Plot Losses
plt.subplot(1, 3, 1)
plt.plot(epochs, train_losses, label='Train Loss')
plt.plot(epochs, val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Losses')

# Plot RMSE and MAE
plt.subplot(1, 3, 2)
plt.plot(epochs, rmse_values, label='RMSE')
plt.plot(epochs, mae_values, label='MAE')
plt.xlabel('Epoch')
plt.ylabel('Error')
plt.legend()
plt.title('RMSE & MAE')

plt.tight_layout()
plt.show()

# Plot Learning Rate
plt.subplot(2,2, 3)
plt.plot(epochs, lrs, label='Learning Rate', color='green')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.legend()
plt.title('Learning Rate Progression')

plt.show()

# %%
model.eval()
reconstructions = []
errors = []

with torch.no_grad():
    for batch in DataLoader(TensorDataset(X_tensor), batch_size=32, shuffle=False):
        X_batch = batch[0]
        output = model(X_batch)
        reconstructions.append(output)
        
        # Per-sequence error (MSE)
        batch_errors = torch.mean((output - X_batch) ** 2, dim=(1, 2))  # mean over seq_len and features
        errors.append(batch_errors)

reconstructions = torch.cat(reconstructions)
errors = torch.cat(errors).numpy()  # Shape: [num_sequences]

# %%
threshold = np.percentile(errors, 95)  # Top 5% as anomalies

# %%
anomalies = errors > threshold

# %%
import matplotlib.pyplot as plt

timestamps = df['close_time'].values[SEQ_LEN:]  # align with sequences

plt.figure(figsize=(15, 4))
plt.plot(timestamps, errors, label="Reconstruction Error")
plt.axhline(y=threshold, color='r', linestyle='--', label="Threshold")
plt.fill_between(timestamps, 0, errors, where=anomalies, color='red', alpha=0.3, label="Anomalies")
plt.legend()
plt.title("Anomaly Detection via LSTM Autoencoder")
plt.xlabel("Time")
plt.ylabel("Error")
plt.show()

# %%
# Number of anomalies
print(f"Total anomalies detected: {np.sum(anomalies)}")
# Out:
# Total anomalies detected: 1922

# %%
close_index = df.columns.get_loc("close") - 1  # adjust for SEQ_LEN offset

recon_close = reconstructions[:, -1, close_index].numpy()
actual_close = X_tensor[:, -1, close_index].numpy()

# Save anomaly info
base_index = SEQ_LEN  # offset for aligning with original df
anomaly_df = df.iloc[base_index:][anomalies].copy()  # only anomalies

anomaly_df['predicted_close'] = recon_close[anomalies]
anomaly_df['actual_close'] = actual_close[anomalies]
anomaly_df['abs_error'] = np.abs(anomaly_df['actual_close'] - anomaly_df['predicted_close'])

anomaly_df.to_csv("results/lstm_autoencoder_anomalies.csv", index=False)
print("Anomalies saved to lstm_autoencoder_anomalies.csv")
# Out:
# Anomalies saved to lstm_autoencoder_anomalies.csv

# %%
df2 = pd.read_csv("results/lstm_autoencoder_anomalies.csv")

# %%
df2.head()
# Out:
#       open     high      low    close       volume  \
# 0  7686.93  7739.80  7627.00  7683.18  3525.785109
# 1  7683.18  7735.94  7577.00  7644.00  2964.576258
# 2  7644.00  7650.00  7582.31  7614.21  2132.633589
# 3  7618.00  7625.00  7542.00  7619.00  2314.600659
# 4  7619.00  7775.00  7607.36  7688.00  3034.183770
#
#                          close_time         quote  takers_buy_base  \
# 0  2018-04-12 08:59:59.999000-05:00  2.710017e+07      1662.304104
# 1  2018-04-12 09:59:59.999000-05:00  2.272880e+07      1410.340431
# 2  2018-04-12 10:59:59.999000-05:00  1.625165e+07      1214.426837
# 3  2018-04-12 11:59:59.999000-05:00  1.757994e+07      1212.220074
# 4  2018-04-12 12:59:59.999000-05:00  2.335782e+07      1622.837760
#
#    takers_buy_quote  predicted_close  actual_close  abs_error
# 0      1.278317e+07         0.066332      0.072414   0.006082
# 1      1.081835e+07         0.067441      0.073285   0.005844
# 2      9.254198e+06         0.068159      0.072523   0.004364
# 3      9.211534e+06         0.068784      0.072604   0.003820
# 4      1.249711e+07         0.069284      0.071990   0.002706
