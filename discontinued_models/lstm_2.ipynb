# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

# %%
# Load and preprocess dataset
df = pd.read_csv("./data/BTCUSDT_1h.csv")
df['close_time'] = pd.to_datetime(df['close_time'], errors='coerce')
df.sort_values('close_time')
data = df[['open', 'high', 'low', 'close', 'volume']].values

# %%
# Normalize
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)

# %%
# Create sequences
SEQ_LEN = 24  # 24 hours
def create_sequences(data, seq_len):
    xs, ys = [], []
    for i in range(len(data) - seq_len):
        x = data[i:i+seq_len]
        y = data[i+seq_len][3]  # Predict 'close'
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

X, y = create_sequences(data_scaled, SEQ_LEN)
split = int(0.8 * len(X))
X_train, y_train = X[:split], y[:split]
X_val, y_val = X[split:], y[split:]

# %%
# Convert to PyTorch tensors
X_train_t = torch.tensor(X_train, dtype=torch.float32)
y_train_t = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1)
X_val_t = torch.tensor(X_val, dtype=torch.float32)
y_val_t = torch.tensor(y_val, dtype=torch.float32).unsqueeze(1)

train_loader = DataLoader(TensorDataset(X_train_t, y_train_t), batch_size=64, shuffle=True)
val_loader = DataLoader(TensorDataset(X_val_t, y_val_t), batch_size=64)

# %%
# LSTM Model
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size=64, num_layers=2, dropout=0.3):
        super().__init__()
        self.lstm = nn.LSTM(input_size=input_size,
                            hidden_size=hidden_size,
                            num_layers=num_layers,
                            batch_first=True,
                            dropout=dropout)
        self.layer_norm = nn.LayerNorm(hidden_size)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        out, _ = self.lstm(x)              # out: [batch, seq_len, hidden]
        out = out[:, -1, :]                # last time step
        out = self.layer_norm(out)         # layer normalization
        out = self.dropout(out)            # apply dropout
        return self.fc(out)

model = LSTMModel(input_size=5, hidden_size=64, num_layers=2, dropout=0.3)

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5, factor=0.5)
early_stopper_patience = 10

# %%
# Training loop
train_losses, val_losses, lrs, rmse_values, mae_values = [], [], [], [], []
best_val_loss = np.inf
patience_counter = 0

for epoch in range(100):
    model.train()
    epoch_train_loss = 0
    for xb, yb in train_loader:
        optimizer.zero_grad()
        pred = model(xb)
        loss = criterion(pred, yb)
        loss.backward()
        optimizer.step()
        epoch_train_loss += loss.item()
    
    model.eval()
    epoch_val_loss = 0
    preds, targets = [], []
    with torch.no_grad():
        for xb, yb in val_loader:
            pred = model(xb)
            loss = criterion(pred, yb)
            epoch_val_loss += loss.item()
            preds.extend(pred.squeeze().tolist())
            targets.extend(yb.squeeze().tolist())

    rmse = np.sqrt(mean_squared_error(targets, preds))
    mae = mean_absolute_error(targets, preds)

    lr = optimizer.param_groups[0]['lr']
    scheduler.step(epoch_val_loss)

    train_losses.append(epoch_train_loss / len(train_loader))
    val_losses.append(epoch_val_loss / len(val_loader))
    lrs.append(lr)
    rmse_values.append(rmse)
    mae_values.append(mae)

    print(f"Epoch {epoch+1}: Train Loss={train_losses[-1]:.4f}, Val Loss={val_losses[-1]:.4f}, \n\tRMSE={rmse:.4f}, MAE={mae:.4f}, LR={lr:.5f}")

    if val_losses[-1] < best_val_loss:
        best_val_loss = val_losses[-1]
        patience_counter = 0
    else:
        patience_counter += 1
        if patience_counter >= early_stopper_patience:
            print("Early stopping triggered.")
            break
# Out:
# Epoch 1: Train Loss=0.0252, Val Loss=0.0099,
# 	RMSE=0.0997, MAE=0.0896, LR=0.01000
# Epoch 2: Train Loss=0.0005, Val Loss=0.0012,
# 	RMSE=0.0341, MAE=0.0232, LR=0.01000
# Epoch 3: Train Loss=0.0004, Val Loss=0.0025,
# 	RMSE=0.0502, MAE=0.0390, LR=0.01000
# Epoch 4: Train Loss=0.0003, Val Loss=0.0043,
# 	RMSE=0.0656, MAE=0.0466, LR=0.01000
# Epoch 5: Train Loss=0.0003, Val Loss=0.0043,
# 	RMSE=0.0655, MAE=0.0486, LR=0.01000
# Epoch 6: Train Loss=0.0003, Val Loss=0.0046,
# 	RMSE=0.0680, MAE=0.0612, LR=0.01000
# Epoch 7: Train Loss=0.0003, Val Loss=0.0012,
# 	RMSE=0.0346, MAE=0.0299, LR=0.01000
# Epoch 8: Train Loss=0.0004, Val Loss=0.0009,
# 	RMSE=0.0303, MAE=0.0256, LR=0.01000
# Epoch 9: Train Loss=0.0003, Val Loss=0.0010,
# 	RMSE=0.0320, MAE=0.0267, LR=0.01000
# Epoch 10: Train Loss=0.0003, Val Loss=0.0011,
# 	RMSE=0.0327, MAE=0.0259, LR=0.01000
# Epoch 11: Train Loss=0.0003, Val Loss=0.0019,
# 	RMSE=0.0440, MAE=0.0351, LR=0.01000
# Epoch 12: Train Loss=0.0002, Val Loss=0.0014,
# 	RMSE=0.0372, MAE=0.0261, LR=0.01000
# Epoch 13: Train Loss=0.0002, Val Loss=0.0034,
# 	RMSE=0.0582, MAE=0.0496, LR=0.01000
# Epoch 14: Train Loss=0.0002, Val Loss=0.0010,
# 	RMSE=0.0309, MAE=0.0274, LR=0.01000
# Epoch 15: Train Loss=0.0002, Val Loss=0.0010,
# 	RMSE=0.0325, MAE=0.0216, LR=0.00500
# Epoch 16: Train Loss=0.0002, Val Loss=0.0025,
# 	RMSE=0.0502, MAE=0.0386, LR=0.00500
# Epoch 17: Train Loss=0.0002, Val Loss=0.0049,
# 	RMSE=0.0700, MAE=0.0635, LR=0.00500
# Epoch 18: Train Loss=0.0002, Val Loss=0.0019,
# 	RMSE=0.0437, MAE=0.0322, LR=0.00500
# Early stopping triggered.

# %%
# Plot metrics
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.legend()
plt.title('Losses')

plt.subplot(1, 2, 2)
plt.plot(lrs, label='Learning Rate')
plt.plot(rmse_values, label='RMSE')
plt.plot(mae_values, label='MAE')
plt.legend()
plt.title('LR, RMSE, MAE')
plt.tight_layout()
plt.show()

# %%
# Detect anomalies using Z-score of residuals
errors = np.abs(np.array(targets) - np.array(preds))
mean_error = np.mean(errors)
std_error = np.std(errors)
z_scores = (errors - mean_error) / std_error

anomaly_threshold = 2.5 
anomalies = np.where(np.abs(z_scores) > anomaly_threshold)[0]

print(f"Detected {len(anomalies)} anomalies using Z-score method.")

# Plot with anomalies
plt.figure(figsize=(14, 6))
plt.plot(targets, label='Actual', alpha=0.6)
plt.plot(preds, label='Predicted', alpha=0.6)
plt.scatter(anomalies, np.array(targets)[anomalies], color='red', label='Anomalies')
plt.title("BTC Closing Price Prediction with Anomalies")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Detected 185 anomalies using Z-score method.

# %%
base_index = split + SEQ_LEN
anomaly_times = df['close_time'].iloc[base_index + anomalies]
for time in anomaly_times:
    print("Anomaly detected at:", time)
# Out:
# Anomaly detected at: 2021-04-13 03:59:59.999000-05:00
# Anomaly detected at: 2021-04-13 04:59:59.999000-05:00
# Anomaly detected at: 2021-04-13 05:59:59.999000-05:00
# Anomaly detected at: 2021-04-13 10:59:59.999000-05:00
# Anomaly detected at: 2021-04-13 12:59:59.999000-05:00
# Anomaly detected at: 2021-04-13 18:59:59.999000-05:00
# Anomaly detected at: 2021-04-13 22:59:59.999000-05:00
# Anomaly detected at: 2021-04-13 23:59:59.999000-05:00
# Anomaly detected at: 2021-04-14 00:59:59.999000-05:00
# Anomaly detected at: 2021-04-14 01:59:59.999000-05:00
# Anomaly detected at: 2021-04-14 02:59:59.999000-05:00
# Anomaly detected at: 2021-04-14 05:59:59.999000-05:00
# Anomaly detected at: 2021-04-14 06:59:59.999000-05:00
# Anomaly detected at: 2021-10-19 14:59:59.999000-05:00
# Anomaly detected at: 2021-10-19 15:59:59.999000-05:00
# Anomaly detected at: 2021-10-19 16:59:59.999000-05:00
# Anomaly detected at: 2021-10-19 17:59:59.999000-05:00
# Anomaly detected at: 2021-10-19 18:59:59.999000-05:00
# Anomaly detected at: 2021-10-19 19:59:59.999000-05:00
# Anomaly detected at: 2021-10-19 23:59:59.999000-05:00
# Anomaly detected at: 2021-10-20 07:59:59.999000-05:00
# Anomaly detected at: 2021-10-20 08:59:59.999000-05:00
# Anomaly detected at: 2021-10-20 09:59:59.999000-05:00
# Anomaly detected at: 2021-10-20 10:59:59.999000-05:00
# Anomaly detected at: 2021-10-20 11:59:59.999000-05:00
# Anomaly detected at: 2021-10-20 12:59:59.999000-05:00
# Anomaly detected at: 2021-10-20 13:59:59.999000-05:00
# Anomaly detected at: 2021-10-20 14:59:59.999000-05:00
# Anomaly detected at: 2021-10-20 15:59:59.999000-05:00
# Anomaly detected at: 2021-10-20 16:59:59.999000-05:00
# Anomaly detected at: 2021-10-20 17:59:59.999000-05:00
# Anomaly detected at: 2021-10-20 18:59:59.999000-05:00
# Anomaly detected at: 2021-10-20 19:59:59.999000-05:00
# Anomaly detected at: 2021-10-20 20:59:59.999000-05:00
# Anomaly detected at: 2021-10-20 21:59:59.999000-05:00
# Anomaly detected at: 2021-10-20 22:59:59.999000-05:00
# Anomaly detected at: 2021-10-20 23:59:59.999000-05:00
# Anomaly detected at: 2021-10-21 00:59:59.999000-05:00
# Anomaly detected at: 2021-10-21 01:59:59.999000-05:00
# Anomaly detected at: 2021-10-21 02:59:59.999000-05:00
# Anomaly detected at: 2021-10-21 03:59:59.999000-05:00
# Anomaly detected at: 2021-10-21 04:59:59.999000-05:00
# Anomaly detected at: 2021-10-21 05:59:59.999000-05:00
# Anomaly detected at: 2021-10-21 06:59:59.999000-05:00
# Anomaly detected at: 2021-10-21 07:59:59.999000-05:00
# Anomaly detected at: 2021-10-21 08:59:59.999000-05:00
# Anomaly detected at: 2021-10-25 10:59:59.999000-05:00
# Anomaly detected at: 2021-10-25 11:59:59.999000-05:00
# Anomaly detected at: 2021-11-02 05:59:59.999000-05:00
# Anomaly detected at: 2021-11-02 10:59:59.999000-05:00
# Anomaly detected at: 2021-11-02 11:59:59.999000-05:00
# Anomaly detected at: 2021-11-07 19:59:59.999000-05:00
# Anomaly detected at: 2021-11-07 20:59:59.999000-05:00
# Anomaly detected at: 2021-11-07 21:59:59.999000-05:00
# Anomaly detected at: 2021-11-07 22:59:59.999000-05:00
# Anomaly detected at: 2021-11-07 23:59:59.999000-05:00
# Anomaly detected at: 2021-11-08 00:59:59.999000-05:00
# Anomaly detected at: 2021-11-08 01:59:59.999000-05:00
# Anomaly detected at: 2021-11-08 02:59:59.999000-05:00
# Anomaly detected at: 2021-11-08 03:59:59.999000-05:00
# Anomaly detected at: 2021-11-08 04:59:59.999000-05:00
# Anomaly detected at: 2021-11-08 05:59:59.999000-05:00
# Anomaly detected at: 2021-11-08 06:59:59.999000-05:00
# Anomaly detected at: 2021-11-08 07:59:59.999000-05:00
# Anomaly detected at: 2021-11-08 08:59:59.999000-05:00
# Anomaly detected at: 2021-11-08 09:59:59.999000-05:00
# Anomaly detected at: 2021-11-08 10:59:59.999000-05:00
# Anomaly detected at: 2021-11-08 11:59:59.999000-05:00
# Anomaly detected at: 2021-11-08 12:59:59.999000-05:00
# Anomaly detected at: 2021-11-08 13:59:59.999000-05:00
# Anomaly detected at: 2021-11-08 14:59:59.999000-05:00
# Anomaly detected at: 2021-11-08 15:59:59.999000-05:00
# Anomaly detected at: 2021-11-08 16:59:59.999000-05:00
# Anomaly detected at: 2021-11-08 17:59:59.999000-05:00
# Anomaly detected at: 2021-11-08 18:59:59.999000-05:00
# Anomaly detected at: 2021-11-08 19:59:59.999000-05:00
# Anomaly detected at: 2021-11-08 20:59:59.999000-05:00
# Anomaly detected at: 2021-11-08 21:59:59.999000-05:00
# Anomaly detected at: 2021-11-08 22:59:59.999000-05:00
# Anomaly detected at: 2021-11-08 23:59:59.999000-05:00
# Anomaly detected at: 2021-11-09 00:59:59.999000-05:00
# Anomaly detected at: 2021-11-09 01:59:59.999000-05:00
# Anomaly detected at: 2021-11-09 02:59:59.999000-05:00
# Anomaly detected at: 2021-11-09 03:59:59.999000-05:00
# Anomaly detected at: 2021-11-09 04:59:59.999000-05:00
# Anomaly detected at: 2021-11-09 05:59:59.999000-05:00
# Anomaly detected at: 2021-11-09 06:59:59.999000-05:00
# Anomaly detected at: 2021-11-09 07:59:59.999000-05:00
# Anomaly detected at: 2021-11-09 08:59:59.999000-05:00
# Anomaly detected at: 2021-11-09 09:59:59.999000-05:00
# Anomaly detected at: 2021-11-09 10:59:59.999000-05:00
# Anomaly detected at: 2021-11-09 11:59:59.999000-05:00
# Anomaly detected at: 2021-11-09 12:59:59.999000-05:00
# Anomaly detected at: 2021-11-09 13:59:59.999000-05:00
# Anomaly detected at: 2021-11-09 14:59:59.999000-05:00
# Anomaly detected at: 2021-11-09 15:59:59.999000-05:00
# Anomaly detected at: 2021-11-09 16:59:59.999000-05:00
# Anomaly detected at: 2021-11-09 17:59:59.999000-05:00
# Anomaly detected at: 2021-11-09 18:59:59.999000-05:00
# Anomaly detected at: 2021-11-09 19:59:59.999000-05:00
# Anomaly detected at: 2021-11-09 20:59:59.999000-05:00
# Anomaly detected at: 2021-11-09 21:59:59.999000-05:00
# Anomaly detected at: 2021-11-09 22:59:59.999000-05:00
# Anomaly detected at: 2021-11-09 23:59:59.999000-05:00
# Anomaly detected at: 2021-11-10 00:59:59.999000-05:00
# Anomaly detected at: 2021-11-10 01:59:59.999000-05:00
# Anomaly detected at: 2021-11-10 02:59:59.999000-05:00
# Anomaly detected at: 2021-11-10 03:59:59.999000-05:00
# Anomaly detected at: 2021-11-10 04:59:59.999000-05:00
# Anomaly detected at: 2021-11-10 05:59:59.999000-05:00
# Anomaly detected at: 2021-11-10 06:59:59.999000-05:00
# Anomaly detected at: 2021-11-10 07:59:59.999000-05:00
# Anomaly detected at: 2021-11-10 08:59:59.999000-05:00
# Anomaly detected at: 2021-11-10 09:59:59.999000-05:00
# Anomaly detected at: 2021-11-10 10:59:59.999000-05:00
# Anomaly detected at: 2021-11-10 11:59:59.999000-05:00
# Anomaly detected at: 2021-11-10 12:59:59.999000-05:00
# Anomaly detected at: 2021-11-10 13:59:59.999000-05:00
# Anomaly detected at: 2021-11-10 14:59:59.999000-05:00
# Anomaly detected at: 2021-11-10 15:59:59.999000-05:00
# Anomaly detected at: 2021-11-10 17:59:59.999000-05:00
# Anomaly detected at: 2021-11-10 18:59:59.999000-05:00
# Anomaly detected at: 2021-11-10 19:59:59.999000-05:00
# Anomaly detected at: 2021-11-11 00:59:59.999000-05:00
# Anomaly detected at: 2021-11-11 01:59:59.999000-05:00
# Anomaly detected at: 2021-11-11 02:59:59.999000-05:00
# Anomaly detected at: 2021-11-11 03:59:59.999000-05:00
# Anomaly detected at: 2021-11-11 04:59:59.999000-05:00
# Anomaly detected at: 2021-11-11 05:59:59.999000-05:00
# Anomaly detected at: 2021-11-11 06:59:59.999000-05:00
# Anomaly detected at: 2021-11-11 07:59:59.999000-05:00
# Anomaly detected at: 2021-11-11 09:59:59.999000-05:00
# Anomaly detected at: 2021-11-11 10:59:59.999000-05:00
# Anomaly detected at: 2021-11-11 11:59:59.999000-05:00
# Anomaly detected at: 2021-11-11 12:59:59.999000-05:00
# Anomaly detected at: 2021-11-11 13:59:59.999000-05:00
# Anomaly detected at: 2021-11-11 14:59:59.999000-05:00
# Anomaly detected at: 2021-11-11 15:59:59.999000-05:00
# Anomaly detected at: 2021-11-11 16:59:59.999000-05:00
# Anomaly detected at: 2021-11-11 17:59:59.999000-05:00
# Anomaly detected at: 2021-11-11 18:59:59.999000-05:00
# Anomaly detected at: 2021-11-11 19:59:59.999000-05:00
# Anomaly detected at: 2021-11-11 20:59:59.999000-05:00
# Anomaly detected at: 2021-11-11 21:59:59.999000-05:00
# Anomaly detected at: 2021-11-11 22:59:59.999000-05:00
# Anomaly detected at: 2021-11-11 23:59:59.999000-05:00
# Anomaly detected at: 2021-11-12 00:59:59.999000-05:00
# Anomaly detected at: 2021-11-12 03:59:59.999000-05:00
# Anomaly detected at: 2021-11-12 19:59:59.999000-05:00
# Anomaly detected at: 2021-11-13 09:59:59.999000-05:00
# Anomaly detected at: 2021-11-13 10:59:59.999000-05:00
# Anomaly detected at: 2021-11-13 11:59:59.999000-05:00
# Anomaly detected at: 2021-11-13 12:59:59.999000-05:00
# Anomaly detected at: 2021-11-13 15:59:59.999000-05:00
# Anomaly detected at: 2021-11-13 16:59:59.999000-05:00
# Anomaly detected at: 2021-11-13 17:59:59.999000-05:00
# Anomaly detected at: 2021-11-13 18:59:59.999000-05:00
# Anomaly detected at: 2021-11-13 19:59:59.999000-05:00
# Anomaly detected at: 2021-11-13 20:59:59.999000-05:00
# Anomaly detected at: 2021-11-13 21:59:59.999000-05:00
# Anomaly detected at: 2021-11-13 22:59:59.999000-05:00
# Anomaly detected at: 2021-11-13 23:59:59.999000-05:00
# Anomaly detected at: 2021-11-14 00:59:59.999000-05:00
# Anomaly detected at: 2021-11-14 01:59:59.999000-05:00
# Anomaly detected at: 2021-11-14 02:59:59.999000-05:00
# Anomaly detected at: 2021-11-14 06:59:59.999000-05:00
# Anomaly detected at: 2021-11-14 07:59:59.999000-05:00
# Anomaly detected at: 2021-11-14 08:59:59.999000-05:00
# Anomaly detected at: 2021-11-14 17:59:59.999000-05:00
# Anomaly detected at: 2021-11-14 18:59:59.999000-05:00
# Anomaly detected at: 2021-11-14 19:59:59.999000-05:00
# Anomaly detected at: 2021-11-14 20:59:59.999000-05:00
# Anomaly detected at: 2021-11-14 21:59:59.999000-05:00
# Anomaly detected at: 2021-11-14 22:59:59.999000-05:00
# Anomaly detected at: 2021-11-14 23:59:59.999000-05:00
# Anomaly detected at: 2021-11-15 00:59:59.999000-05:00
# Anomaly detected at: 2021-11-15 01:59:59.999000-05:00
# Anomaly detected at: 2021-11-15 02:59:59.999000-05:00
# Anomaly detected at: 2021-11-15 03:59:59.999000-05:00
# Anomaly detected at: 2021-11-15 04:59:59.999000-05:00
# Anomaly detected at: 2021-11-15 05:59:59.999000-05:00
# Anomaly detected at: 2021-11-15 06:59:59.999000-05:00
# Anomaly detected at: 2021-11-15 07:59:59.999000-05:00
# Anomaly detected at: 2021-11-15 08:59:59.999000-05:00
# Anomaly detected at: 2021-11-15 09:59:59.999000-05:00

# %%
anomaly_df = df.iloc[base_index + anomalies].copy()
anomaly_df['predicted_close'] = np.array(preds)[anomalies]
anomaly_df['actual_close'] = np.array(targets)[anomalies]
anomaly_df['abs_error'] = np.abs(anomaly_df['actual_close'] - anomaly_df['predicted_close'])

anomaly_df.to_csv("./results/lstm_anomalies_upgraded.csv", index=False)
print("Anomalies saved to lstm_anomalies_upgraded.csv")
# Out:
# Anomalies saved to lstm_anomalies_upgraded.csv

# %%
df2 = pd.read_csv("./results/lstm_anomalies_upgraded.csv")

# %%
df2.head()
# Out:
#        open      high       low     close        volume  \
# 0  61050.99  62878.00  61046.45  62711.51  11272.865488
# 1  62711.51  63287.88  62300.88  62924.24   6333.624079
# 2  62924.23  63100.00  62458.00  62745.56   4400.767576
# 3  62745.56  63093.82  62500.00  62942.21   3337.013558
# 4  62942.21  63260.00  62790.85  62973.25   4125.909956
#
#                          close_time         quote  takers_buy_base  \
# 0  2021-04-13 03:59:59.999000-05:00  7.022088e+08      6269.806143
# 1  2021-04-13 04:59:59.999000-05:00  3.975447e+08      3605.461764
# 2  2021-04-13 05:59:59.999000-05:00  2.760403e+08      2191.675626
# 3  2021-04-13 06:59:59.999000-05:00  2.096540e+08      1549.536054
# 4  2021-04-13 07:59:59.999000-05:00  2.598547e+08      1754.848356
#
#    takers_buy_quote  predicted_close  actual_close  abs_error
# 0      3.903930e+08         0.793523      0.909880   0.116357
# 1      2.263464e+08         0.794345      0.913118   0.118773
# 2      1.374780e+08         0.796925      0.910399   0.113474
# 3      9.735709e+07         0.799723      0.913391   0.113668
# 4      1.105400e+08         0.802088      0.913863   0.111775
