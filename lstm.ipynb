# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

# Load and preprocess dataset
df = pd.read_csv("./data/BTCUSDT_1h.csv")
df['close_time'] = pd.to_datetime(df['close_time'], errors='coerce')
df.sort_values('close_time')
data = df[['open', 'high', 'low', 'close', 'volume']].values

# Normalize
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)

# Create sequences
SEQ_LEN = 24  # 24 hours
def create_sequences(data, seq_len):
    xs, ys = [], []
    for i in range(len(data) - seq_len):
        x = data[i:i+seq_len]
        y = data[i+seq_len][3]  # Predict 'close'
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

X, y = create_sequences(data_scaled, SEQ_LEN)
split = int(0.8 * len(X))
X_train, y_train = X[:split], y[:split]
X_val, y_val = X[split:], y[split:]

# Convert to PyTorch tensors
X_train_t = torch.tensor(X_train, dtype=torch.float32)
y_train_t = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1)
X_val_t = torch.tensor(X_val, dtype=torch.float32)
y_val_t = torch.tensor(y_val, dtype=torch.float32).unsqueeze(1)

train_loader = DataLoader(TensorDataset(X_train_t, y_train_t), batch_size=64, shuffle=True)
val_loader = DataLoader(TensorDataset(X_val_t, y_val_t), batch_size=64)

# LSTM Model
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size=64):
        super().__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = out[:, -1]
        return self.fc(out)

model = LSTMModel(input_size=5)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5, factor=0.5)
early_stopper_patience = 10

# Training loop
train_losses, val_losses, lrs, rmse_values, mae_values = [], [], [], [], []
best_val_loss = np.inf
patience_counter = 0

for epoch in range(100):
    model.train()
    epoch_train_loss = 0
    for xb, yb in train_loader:
        optimizer.zero_grad()
        pred = model(xb)
        loss = criterion(pred, yb)
        loss.backward()
        optimizer.step()
        epoch_train_loss += loss.item()
    
    model.eval()
    epoch_val_loss = 0
    preds, targets = [], []
    with torch.no_grad():
        for xb, yb in val_loader:
            pred = model(xb)
            loss = criterion(pred, yb)
            epoch_val_loss += loss.item()
            preds.extend(pred.squeeze().tolist())
            targets.extend(yb.squeeze().tolist())

    rmse = np.sqrt(mean_squared_error(targets, preds))
    mae = mean_absolute_error(targets, preds)

    lr = optimizer.param_groups[0]['lr']
    scheduler.step(epoch_val_loss)

    train_losses.append(epoch_train_loss / len(train_loader))
    val_losses.append(epoch_val_loss / len(val_loader))
    lrs.append(lr)
    rmse_values.append(rmse)
    mae_values.append(mae)

    print(f"Epoch {epoch+1}: Train Loss={train_losses[-1]:.4f}, Val Loss={val_losses[-1]:.4f}, \n\tRMSE={rmse:.4f}, MAE={mae:.4f}, LR={lr:.5f}")

    if val_losses[-1] < best_val_loss:
        best_val_loss = val_losses[-1]
        patience_counter = 0
    else:
        patience_counter += 1
        if patience_counter >= early_stopper_patience:
            print("Early stopping triggered.")
            break

# Plot metrics
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.legend()
plt.title('Losses')

plt.subplot(1, 2, 2)
plt.plot(lrs, label='Learning Rate')
plt.plot(rmse_values, label='RMSE')
plt.plot(mae_values, label='MAE')
plt.legend()
plt.title('LR, RMSE, MAE')
plt.tight_layout()
plt.show()
# Out:
# Epoch 1: Train Loss=0.0002, Val Loss=0.0005, RMSE=0.0224, MAE=0.0205, LR=0.01000
# Epoch 2: Train Loss=0.0000, Val Loss=0.0001, RMSE=0.0095, MAE=0.0075, LR=0.01000
# Epoch 3: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0069, MAE=0.0049, LR=0.01000
# Epoch 4: Train Loss=0.0000, Val Loss=0.0002, RMSE=0.0142, MAE=0.0128, LR=0.01000
# Epoch 5: Train Loss=0.0000, Val Loss=0.0001, RMSE=0.0078, MAE=0.0060, LR=0.01000
# Epoch 6: Train Loss=0.0000, Val Loss=0.0001, RMSE=0.0086, MAE=0.0069, LR=0.01000
# Epoch 7: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0067, MAE=0.0048, LR=0.01000
# Epoch 8: Train Loss=0.0000, Val Loss=0.0003, RMSE=0.0172, MAE=0.0158, LR=0.01000
# Epoch 9: Train Loss=0.0000, Val Loss=0.0001, RMSE=0.0092, MAE=0.0074, LR=0.01000
# Epoch 10: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0064, MAE=0.0045, LR=0.01000
# Epoch 11: Train Loss=0.0000, Val Loss=0.0001, RMSE=0.0106, MAE=0.0086, LR=0.01000
# Epoch 12: Train Loss=0.0000, Val Loss=0.0001, RMSE=0.0108, MAE=0.0094, LR=0.01000
# Epoch 13: Train Loss=0.0000, Val Loss=0.0001, RMSE=0.0085, MAE=0.0068, LR=0.01000
# Epoch 14: Train Loss=0.0000, Val Loss=0.0001, RMSE=0.0091, MAE=0.0073, LR=0.01000
# Epoch 15: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0065, MAE=0.0047, LR=0.01000
# Epoch 16: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0063, MAE=0.0044, LR=0.01000
# Epoch 17: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0070, MAE=0.0052, LR=0.01000
# Epoch 18: Train Loss=0.0000, Val Loss=0.0001, RMSE=0.0071, MAE=0.0053, LR=0.01000
# Epoch 19: Train Loss=0.0000, Val Loss=0.0001, RMSE=0.0071, MAE=0.0053, LR=0.01000
# Epoch 20: Train Loss=0.0000, Val Loss=0.0002, RMSE=0.0134, MAE=0.0120, LR=0.01000
# Epoch 21: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0064, MAE=0.0046, LR=0.01000
# Epoch 22: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0069, MAE=0.0050, LR=0.01000
# Epoch 23: Train Loss=0.0000, Val Loss=0.0001, RMSE=0.0092, MAE=0.0075, LR=0.00500
# Epoch 24: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0061, MAE=0.0043, LR=0.00500
# Epoch 25: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0065, MAE=0.0046, LR=0.00500
# Epoch 26: Train Loss=0.0000, Val Loss=0.0001, RMSE=0.0073, MAE=0.0056, LR=0.00500
# Epoch 27: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0061, MAE=0.0042, LR=0.00500
# Epoch 28: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0062, MAE=0.0044, LR=0.00500
# Epoch 29: Train Loss=0.0000, Val Loss=0.0001, RMSE=0.0087, MAE=0.0069, LR=0.00500
# Epoch 30: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0061, MAE=0.0043, LR=0.00500
# Epoch 31: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0064, MAE=0.0046, LR=0.00500
# Epoch 32: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0061, MAE=0.0043, LR=0.00500
# Epoch 33: Train Loss=0.0000, Val Loss=0.0001, RMSE=0.0086, MAE=0.0070, LR=0.00500
# Epoch 34: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0070, MAE=0.0052, LR=0.00250
# Epoch 35: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0064, MAE=0.0046, LR=0.00250
# Epoch 36: Train Loss=0.0000, Val Loss=0.0001, RMSE=0.0097, MAE=0.0082, LR=0.00250
# Epoch 37: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0061, MAE=0.0042, LR=0.00250
# Epoch 38: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0063, MAE=0.0045, LR=0.00250
# Epoch 39: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0062, MAE=0.0044, LR=0.00250
# Epoch 40: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0061, MAE=0.0042, LR=0.00250
# Epoch 41: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0061, MAE=0.0042, LR=0.00250
# Epoch 42: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0061, MAE=0.0042, LR=0.00250
# Epoch 43: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0060, MAE=0.0041, LR=0.00250
# Epoch 44: Train Loss=0.0000, Val Loss=0.0001, RMSE=0.0084, MAE=0.0067, LR=0.00250
# Epoch 45: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0063, MAE=0.0044, LR=0.00250
# Epoch 46: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0061, MAE=0.0042, LR=0.00250
# Epoch 47: Train Loss=0.0000, Val Loss=0.0001, RMSE=0.0096, MAE=0.0079, LR=0.00250
# Epoch 48: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0062, MAE=0.0043, LR=0.00250
# Epoch 49: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0062, MAE=0.0044, LR=0.00250
# Epoch 50: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0061, MAE=0.0042, LR=0.00125
# Epoch 51: Train Loss=0.0000, Val Loss=0.0001, RMSE=0.0081, MAE=0.0065, LR=0.00125
# Epoch 52: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0063, MAE=0.0045, LR=0.00125
# Epoch 53: Train Loss=0.0000, Val Loss=0.0000, RMSE=0.0067, MAE=0.0048, LR=0.00125
# Early stopping triggered.

# %%
# Detect anomalies using Z-score of residuals
errors = np.abs(np.array(targets) - np.array(preds))
mean_error = np.mean(errors)
std_error = np.std(errors)
z_scores = (errors - mean_error) / std_error

anomaly_threshold = 2.5  # Can tune this
anomalies = np.where(np.abs(z_scores) > anomaly_threshold)[0]

print(f"Detected {len(anomalies)} anomalies using Z-score method.")

# Plot with anomalies
plt.figure(figsize=(14, 6))
plt.plot(targets, label='Actual', alpha=0.6)
plt.plot(preds, label='Predicted', alpha=0.6)
plt.scatter(anomalies, np.array(targets)[anomalies], color='red', label='Anomalies')
plt.title("BTC Closing Price Prediction with Anomalies")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Detected 222 anomalies using Z-score method.

# %%
base_index = split + SEQ_LEN
anomaly_times = df['close_time'].iloc[base_index + anomalies]
for time in anomaly_times:
    print("Anomaly detected at:", time)
# Out:
# Anomaly detected at: 2021-02-24 05:59:59.999000-05:00
# Anomaly detected at: 2021-02-24 08:59:59.999000-05:00
# Anomaly detected at: 2021-02-25 07:59:59.999000-05:00
# Anomaly detected at: 2021-02-25 12:59:59.999000-05:00
# Anomaly detected at: 2021-02-25 16:59:59.999000-05:00
# Anomaly detected at: 2021-02-25 18:59:59.999000-05:00
# Anomaly detected at: 2021-02-26 00:59:59.999000-05:00
# Anomaly detected at: 2021-02-26 02:59:59.999000-05:00
# Anomaly detected at: 2021-02-26 08:59:59.999000-05:00
# Anomaly detected at: 2021-02-27 17:59:59.999000-05:00
# Anomaly detected at: 2021-02-27 21:59:59.999000-05:00
# Anomaly detected at: 2021-02-27 22:59:59.999000-05:00
# Anomaly detected at: 2021-02-28 10:59:59.999000-05:00
# Anomaly detected at: 2021-03-02 11:59:59.999000-05:00
# Anomaly detected at: 2021-03-03 08:59:59.999000-05:00
# Anomaly detected at: 2021-03-03 22:59:59.999000-05:00
# Anomaly detected at: 2021-03-04 04:59:59.999000-05:00
# Anomaly detected at: 2021-03-04 12:59:59.999000-05:00
# Anomaly detected at: 2021-03-04 13:59:59.999000-05:00
# Anomaly detected at: 2021-03-04 19:59:59.999000-05:00
# Anomaly detected at: 2021-03-08 20:59:59.999000-05:00
# Anomaly detected at: 2021-03-09 20:59:59.999000-05:00
# Anomaly detected at: 2021-03-10 18:59:59.999000-05:00
# Anomaly detected at: 2021-03-13 05:59:59.999000-05:00
# Anomaly detected at: 2021-03-14 18:59:59.999000-05:00
# Anomaly detected at: 2021-03-15 02:59:59.999000-05:00
# Anomaly detected at: 2021-03-15 04:59:59.999000-05:00
# Anomaly detected at: 2021-03-15 19:59:59.999000-05:00
# Anomaly detected at: 2021-03-17 04:59:59.999000-05:00
# Anomaly detected at: 2021-03-17 13:59:59.999000-05:00
# Anomaly detected at: 2021-03-18 10:59:59.999000-05:00
# Anomaly detected at: 2021-03-18 13:59:59.999000-05:00
# Anomaly detected at: 2021-03-18 19:59:59.999000-05:00
# Anomaly detected at: 2021-03-21 04:59:59.999000-05:00
# Anomaly detected at: 2021-03-22 14:59:59.999000-05:00
# Anomaly detected at: 2021-03-22 15:59:59.999000-05:00
# Anomaly detected at: 2021-03-24 17:59:59.999000-05:00
# Anomaly detected at: 2021-03-25 07:59:59.999000-05:00
# Anomaly detected at: 2021-03-31 02:59:59.999000-05:00
# Anomaly detected at: 2021-04-09 23:59:59.999000-05:00
# Anomaly detected at: 2021-04-10 15:59:59.999000-05:00
# Anomaly detected at: 2021-04-13 03:59:59.999000-05:00
# Anomaly detected at: 2021-04-14 12:59:59.999000-05:00
# Anomaly detected at: 2021-04-15 23:59:59.999000-05:00
# Anomaly detected at: 2021-04-17 22:59:59.999000-05:00
# Anomaly detected at: 2021-04-18 03:59:59.999000-05:00
# Anomaly detected at: 2021-04-18 06:59:59.999000-05:00
# Anomaly detected at: 2021-04-18 07:59:59.999000-05:00
# Anomaly detected at: 2021-04-19 09:59:59.999000-05:00
# Anomaly detected at: 2021-04-19 10:59:59.999000-05:00
# Anomaly detected at: 2021-04-19 19:59:59.999000-05:00
# Anomaly detected at: 2021-04-20 01:59:59.999000-05:00
# Anomaly detected at: 2021-04-20 09:59:59.999000-05:00
# Anomaly detected at: 2021-04-21 17:59:59.999000-05:00
# Anomaly detected at: 2021-04-22 12:59:59.999000-05:00
# Anomaly detected at: 2021-04-22 15:59:59.999000-05:00
# Anomaly detected at: 2021-04-22 21:59:59.999000-05:00
# Anomaly detected at: 2021-04-23 05:59:59.999000-05:00
# Anomaly detected at: 2021-04-23 19:59:59.999000-05:00
# Anomaly detected at: 2021-04-25 15:59:59.999000-05:00
# Anomaly detected at: 2021-04-25 19:59:59.999000-05:00
# Anomaly detected at: 2021-04-26 15:59:59.999000-05:00
# Anomaly detected at: 2021-04-28 15:59:59.999000-05:00
# Anomaly detected at: 2021-04-30 08:59:59.999000-05:00
# Anomaly detected at: 2021-04-30 10:59:59.999000-05:00
# Anomaly detected at: 2021-05-01 22:59:59.999000-05:00
# Anomaly detected at: 2021-05-03 19:59:59.999000-05:00
# Anomaly detected at: 2021-05-04 10:59:59.999000-05:00
# Anomaly detected at: 2021-05-06 13:59:59.999000-05:00
# Anomaly detected at: 2021-05-08 10:59:59.999000-05:00
# Anomaly detected at: 2021-05-09 07:59:59.999000-05:00
# Anomaly detected at: 2021-05-10 10:59:59.999000-05:00
# Anomaly detected at: 2021-05-10 14:59:59.999000-05:00
# Anomaly detected at: 2021-05-10 21:59:59.999000-05:00
# Anomaly detected at: 2021-05-12 05:59:59.999000-05:00
# Anomaly detected at: 2021-05-12 17:59:59.999000-05:00
# Anomaly detected at: 2021-05-12 18:59:59.999000-05:00
# Anomaly detected at: 2021-05-12 20:59:59.999000-05:00
# Anomaly detected at: 2021-05-13 03:59:59.999000-05:00
# Anomaly detected at: 2021-05-13 11:59:59.999000-05:00
# Anomaly detected at: 2021-05-14 15:59:59.999000-05:00
# Anomaly detected at: 2021-05-15 11:59:59.999000-05:00
# Anomaly detected at: 2021-05-15 18:59:59.999000-05:00
# Anomaly detected at: 2021-05-16 13:59:59.999000-05:00
# Anomaly detected at: 2021-05-16 15:59:59.999000-05:00
# Anomaly detected at: 2021-05-16 19:59:59.999000-05:00
# Anomaly detected at: 2021-05-16 22:59:59.999000-05:00
# Anomaly detected at: 2021-05-17 05:59:59.999000-05:00
# Anomaly detected at: 2021-05-17 10:59:59.999000-05:00
# Anomaly detected at: 2021-05-17 11:59:59.999000-05:00
# Anomaly detected at: 2021-05-17 16:59:59.999000-05:00
# Anomaly detected at: 2021-05-18 07:59:59.999000-05:00
# Anomaly detected at: 2021-05-18 20:59:59.999000-05:00
# Anomaly detected at: 2021-05-18 23:59:59.999000-05:00
# Anomaly detected at: 2021-05-19 07:59:59.999000-05:00
# Anomaly detected at: 2021-05-19 09:59:59.999000-05:00
# Anomaly detected at: 2021-05-19 11:59:59.999000-05:00
# Anomaly detected at: 2021-05-19 13:59:59.999000-05:00
# Anomaly detected at: 2021-05-19 15:59:59.999000-05:00
# Anomaly detected at: 2021-05-19 18:59:59.999000-05:00
# Anomaly detected at: 2021-05-19 19:59:59.999000-05:00
# Anomaly detected at: 2021-05-20 07:59:59.999000-05:00
# Anomaly detected at: 2021-05-20 11:59:59.999000-05:00
# Anomaly detected at: 2021-05-21 09:59:59.999000-05:00
# Anomaly detected at: 2021-05-21 10:59:59.999000-05:00
# Anomaly detected at: 2021-05-21 15:59:59.999000-05:00
# Anomaly detected at: 2021-05-21 16:59:59.999000-05:00
# Anomaly detected at: 2021-05-23 03:59:59.999000-05:00
# Anomaly detected at: 2021-05-23 07:59:59.999000-05:00
# Anomaly detected at: 2021-05-23 11:59:59.999000-05:00
# Anomaly detected at: 2021-05-24 14:59:59.999000-05:00
# Anomaly detected at: 2021-05-26 08:59:59.999000-05:00
# Anomaly detected at: 2021-05-26 20:59:59.999000-05:00
# Anomaly detected at: 2021-05-28 03:59:59.999000-05:00
# Anomaly detected at: 2021-05-28 07:59:59.999000-05:00
# Anomaly detected at: 2021-05-28 11:59:59.999000-05:00
# Anomaly detected at: 2021-05-29 12:59:59.999000-05:00
# Anomaly detected at: 2021-05-30 07:59:59.999000-05:00
# Anomaly detected at: 2021-06-05 04:59:59.999000-05:00
# Anomaly detected at: 2021-06-07 15:59:59.999000-05:00
# Anomaly detected at: 2021-06-07 21:59:59.999000-05:00
# Anomaly detected at: 2021-06-09 10:59:59.999000-05:00
# Anomaly detected at: 2021-06-10 09:59:59.999000-05:00
# Anomaly detected at: 2021-06-13 15:59:59.999000-05:00
# Anomaly detected at: 2021-06-18 13:59:59.999000-05:00
# Anomaly detected at: 2021-06-21 01:59:59.999000-05:00
# Anomaly detected at: 2021-06-21 05:59:59.999000-05:00
# Anomaly detected at: 2021-06-21 16:59:59.999000-05:00
# Anomaly detected at: 2021-06-22 07:59:59.999000-05:00
# Anomaly detected at: 2021-06-22 08:59:59.999000-05:00
# Anomaly detected at: 2021-06-22 10:59:59.999000-05:00
# Anomaly detected at: 2021-06-26 02:59:59.999000-05:00
# Anomaly detected at: 2021-06-27 17:59:59.999000-05:00
# Anomaly detected at: 2021-07-05 06:59:59.999000-05:00
# Anomaly detected at: 2021-07-25 19:59:59.999000-05:00
# Anomaly detected at: 2021-07-25 20:59:59.999000-05:00
# Anomaly detected at: 2021-07-26 15:59:59.999000-05:00
# Anomaly detected at: 2021-07-28 07:59:59.999000-05:00
# Anomaly detected at: 2021-07-28 12:59:59.999000-05:00
# Anomaly detected at: 2021-07-28 13:59:59.999000-05:00
# Anomaly detected at: 2021-07-30 03:59:59.999000-05:00
# Anomaly detected at: 2021-08-06 10:59:59.999000-05:00
# Anomaly detected at: 2021-08-14 05:59:59.999000-05:00
# Anomaly detected at: 2021-08-16 08:59:59.999000-05:00
# Anomaly detected at: 2021-08-25 03:59:59.999000-05:00
# Anomaly detected at: 2021-09-07 03:59:59.999000-05:00
# Anomaly detected at: 2021-09-07 09:59:59.999000-05:00
# Anomaly detected at: 2021-09-07 10:59:59.999000-05:00
# Anomaly detected at: 2021-09-08 01:59:59.999000-05:00
# Anomaly detected at: 2021-09-13 08:59:59.999000-05:00
# Anomaly detected at: 2021-09-13 09:59:59.999000-05:00
# Anomaly detected at: 2021-09-19 21:59:59.999000-05:00
# Anomaly detected at: 2021-09-20 06:59:59.999000-05:00
# Anomaly detected at: 2021-09-20 19:59:59.999000-05:00
# Anomaly detected at: 2021-09-21 15:59:59.999000-05:00
# Anomaly detected at: 2021-09-24 04:59:59.999000-05:00
# Anomaly detected at: 2021-09-26 04:59:59.999000-05:00
# Anomaly detected at: 2021-09-27 18:59:59.999000-05:00
# Anomaly detected at: 2021-10-01 05:59:59.999000-05:00
# Anomaly detected at: 2021-10-06 07:59:59.999000-05:00
# Anomaly detected at: 2021-10-10 16:59:59.999000-05:00
# Anomaly detected at: 2021-10-13 00:59:59.999000-05:00
# Anomaly detected at: 2021-10-14 21:59:59.999000-05:00
# Anomaly detected at: 2021-10-15 11:59:59.999000-05:00
# Anomaly detected at: 2021-10-15 16:59:59.999000-05:00
# Anomaly detected at: 2021-10-16 07:59:59.999000-05:00
# Anomaly detected at: 2021-10-17 15:59:59.999000-05:00
# Anomaly detected at: 2021-10-20 08:59:59.999000-05:00
# Anomaly detected at: 2021-10-21 09:59:59.999000-05:00
# Anomaly detected at: 2021-10-22 08:59:59.999000-05:00
# Anomaly detected at: 2021-10-22 09:59:59.999000-05:00
# Anomaly detected at: 2021-10-23 06:59:59.999000-05:00
# Anomaly detected at: 2021-10-26 16:59:59.999000-05:00
# Anomaly detected at: 2021-10-27 03:59:59.999000-05:00
# Anomaly detected at: 2021-10-28 03:59:59.999000-05:00
# Anomaly detected at: 2021-10-28 13:59:59.999000-05:00
# Anomaly detected at: 2021-10-28 14:59:59.999000-05:00
# Anomaly detected at: 2021-11-01 02:59:59.999000-05:00
# Anomaly detected at: 2021-11-02 04:59:59.999000-05:00
# Anomaly detected at: 2021-11-04 10:59:59.999000-05:00
# Anomaly detected at: 2021-11-07 19:59:59.999000-05:00
# Anomaly detected at: 2021-11-10 08:59:59.999000-05:00
# Anomaly detected at: 2021-11-10 14:59:59.999000-05:00
# Anomaly detected at: 2021-11-10 15:59:59.999000-05:00
# Anomaly detected at: 2021-11-10 16:59:59.999000-05:00
# Anomaly detected at: 2021-11-12 04:59:59.999000-05:00
# Anomaly detected at: 2021-11-15 19:59:59.999000-05:00
# Anomaly detected at: 2021-11-17 05:59:59.999000-05:00
# Anomaly detected at: 2021-11-18 11:59:59.999000-05:00
# Anomaly detected at: 2021-11-18 17:59:59.999000-05:00
# Anomaly detected at: 2021-11-20 13:59:59.999000-05:00
# Anomaly detected at: 2021-11-22 08:59:59.999000-05:00
# Anomaly detected at: 2021-11-22 13:59:59.999000-05:00
# Anomaly detected at: 2021-11-26 03:59:59.999000-05:00
# Anomaly detected at: 2021-11-28 16:59:59.999000-05:00
# Anomaly detected at: 2021-11-28 18:59:59.999000-05:00
# Anomaly detected at: 2021-11-30 00:59:59.999000-05:00
# Anomaly detected at: 2021-11-30 10:59:59.999000-05:00
# Anomaly detected at: 2021-11-30 11:59:59.999000-05:00
# Anomaly detected at: 2021-12-03 09:59:59.999000-05:00
# Anomaly detected at: 2021-12-03 11:59:59.999000-05:00
# Anomaly detected at: 2021-12-03 14:59:59.999000-05:00
# Anomaly detected at: 2021-12-03 19:59:59.999000-05:00
# Anomaly detected at: 2021-12-03 22:59:59.999000-05:00
# Anomaly detected at: 2021-12-03 23:59:59.999000-05:00
# Anomaly detected at: 2021-12-04 00:59:59.999000-05:00
# Anomaly detected at: 2021-12-04 06:59:59.999000-05:00
# Anomaly detected at: 2021-12-05 10:59:59.999000-05:00
# Anomaly detected at: 2021-12-06 04:59:59.999000-05:00
# Anomaly detected at: 2021-12-08 05:59:59.999000-05:00
# Anomaly detected at: 2021-12-08 09:59:59.999000-05:00
# Anomaly detected at: 2021-12-10 09:59:59.999000-05:00
# Anomaly detected at: 2021-12-12 20:59:59.999000-05:00
# Anomaly detected at: 2021-12-17 09:59:59.999000-05:00
# Anomaly detected at: 2021-12-29 18:59:59.999000-05:00
# Anomaly detected at: 2021-12-31 03:59:59.999000-05:00
# Anomaly detected at: 2021-12-31 14:59:59.999000-05:00
# Anomaly detected at: 2022-01-04 13:59:59.999000-05:00
# Anomaly detected at: 2022-01-05 14:59:59.999000-05:00
# Anomaly detected at: 2022-01-05 15:59:59.999000-05:00
# Anomaly detected at: 2022-01-06 22:59:59.999000-05:00
# Anomaly detected at: 2022-01-07 08:59:59.999000-05:00

# %%
anomaly_df = df.iloc[base_index + anomalies].copy()
anomaly_df['predicted_close'] = np.array(preds)[anomalies]
anomaly_df['actual_close'] = np.array(targets)[anomalies]
anomaly_df['abs_error'] = np.abs(anomaly_df['actual_close'] - anomaly_df['predicted_close'])

anomaly_df.to_csv("lstm_anomalies.csv", index=False)
print("Anomalies saved to btc_anomalies.csv")
# Out:
# Anomalies saved to btc_anomalies.csv
